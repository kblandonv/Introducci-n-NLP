# %% [markdown]
# <a href="https://colab.research.google.com/github/kblandonv/Introducci-n-NLP/blob/main/%5BTaller%5D_Introduccio%CC%81n_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![escudoUnal (3).svg](data:image/svg+xml;base64,...)

# %% [markdown]
# # [Taller] Introducción NLP

# %% [markdown]
# Procesamiento de Lenguaje Natural - 3011176

# %% [markdown]
# **Objetivo**
# Realizar unos ejercicios para poner en practica la manipulacion de texto en python
#
# **Contenido**
# - Limpieza de texto
# - Normalización de texto
# - Pyspellchecker

# %% [markdown]
# ##Consideraciones

# %% [markdown]
# Ejecute el cuaderno en orden

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# Teniendo encuenta esta base

# %%
texto1 = "ESTE TEXTO EN MINUSCULAS"
texto2 = "este texto en mayusculas"
nombre = "alejandro jimenez franco"
texto3 = "estE texTo capitAlizado"
apples = """
The history of apples dates back thousands of years, originating in Central Asia,
particularly in Kazakhstan. The word "apple," derived from the Old English "aeppel,"
has appeared frequently in literature and agriculture, symbolizing knowledge and temptation.
Romans cultivated apples, and by the Middle Ages, they were a staple fruit in Europe.
When European settlers brought apples to North America in the 17th century,
they became ingrained in American culture, epitomized by the legendary figure Johnny Appleseed.
Today, apples remain one of the most popular fruits globally,
and the word "apple" continues to represent both tradition and innovation."""
formateo = "My name is {name}, I'm {age}"
palabras = ("Hello", "World", "!")
texto4 = "     programar     "
texto5 = "Jhon loves programming"
texto6 = "Hello_World,_today_is_a_great_day"
texto7 = "El pingüino es un ave no voladora que habita principalmente en el hemisferio sur. Con su plumaje blanco y negro, es un gran nadador y cazador de peces y krill. Viven en colonias y son muy sociables, formando lazos fuertes durante la crianza de sus crías. Su hábitat enfrenta amenazas por el cambio climático y la contaminación."
texto8 = "El examen era mañana y yo aún tenía mucho que estudiar. Me tomé un vaso de leche con azúcar, dejé de mirar el césped por la ventana de la habitación y, aunque era difícil, me puse a estudiar como nunca antes había hecho."

# %% [markdown]
# Haga uso de la siguiente [documentacion](https://www.w3schools.com/python/python_ref_string.asp) de strings en python para completar lo requerido

# %%
# variable: texto1 a minusculas
texto1 = texto1.lower()

print(texto1)

# variable: texto2 a mayusculas
texto2 = texto2.upper()

print(texto2)

# variable: nombre cada primer letra de cada palabra en mayuscula
nombre = nombre.title()
print(nombre)

# variable: texto3 capitalizado
texto3 = texto3.capitalize()

print(texto3)

# variable: apples contar las ocurrencias de la palabra 'apples'
apples_count = apples.lower().count("apples")
print(apples_count)

# variable: apples encontrar en que lugar del texto esta palabra 'aeppel'
aeppel_index = apples.find("aeppel")
print(aeppel_index)

# variable: formateo darle tu nombre y tu edad al texto
formateo = formateo.format(name="Kevin", age=25)
print(formateo)


# variable: palabras unir las palabras con un ' ' (espacio en blanco)
palabras = " ".join(palabras)
print(palabras)

# variable: texto4 quitar los espacios en blanco
texto4 = texto4.strip()
print(texto4)

# variable: texto5 reemplazar la palabra Jhon a tu nombre
texto5 = texto5.replace("Jhon", "Kevin")
print(texto5)

# variable: texto6 separar el texto por el caracter '_'
texto6 = str(texto6)
texto6 = texto6.split('_')
print(texto6)

# variable: texto7 encontrar el indice de la palabra colonias
colonias_index = texto7.find("colonias")
print(texto7)

# variable: texto8 reemplazar o quitar las tildes del texto
texto8 = texto8.replace("á", "a")
print(texto8)

texto8 = texto8.replace("é", "e")
print(texto8)

texto8 = texto8.replace("í", "i")
print(texto8)

texto8 = texto8.replace("ó", "o")
print(texto8)

texto8 = texto8.replace("ú", "u")
print(texto8)

texto8 = texto8.replace("ñ", "n")
print(texto8)
# Out:
# este texto en minusculas
# ESTE TEXTO EN MAYUSCULAS
# Alejandro Jimenez Franco
# Este texto capitalizado
# 5
# 159
# My name is Kevin, I'm 25
# H                                                               e                                                               l                                                               l                                                               o                                                                                                                               W                                                               o                                                               r                                                               l                                                               d                                                                                                                               !
# programar
# Kevin loves programming
# ...

# %% [markdown]
# Complete...
# La diferencia entre `index()` y `find()` es que index retorna una `...`, si no encuentra el valor y find retorna `...` cuando no encuentra dicho valor.

# %% [markdown]
# ## Ejercicio 2

# %% [markdown]
# **Máquina Enigma**,
# fue un dispositivo de cifrado utilizado por los alemanes durante la Segunda Guerra Mundial para proteger comunicaciones. Su funcionamiento se basaba en una serie de rotores y un panel de teclado. Cada vez que se presionaba una tecla, un rotor giraba, cambiando la conexión eléctrica y produciendo una letra codificada.
#
# Los rotores podían configurarse de diferentes maneras, lo que generaba combinaciones casi infinitas de cifrado. Además, la máquina incluía un reflejo que devolvía la señal a través de los rotores, lo que hacía que el mismo mensaje cifrado pudiera ser descifrado si se conocía la configuración exacta de la máquina. La complejidad de Enigma fue un desafío significativo para los criptoanalistas aliados hasta que se desarrollaron métodos y herramientas, como las utilizadas por Alan Turing y su equipo en Bletchley Park, para romper su código.

# %% [markdown]
# Para el ejercicio desarrollaremos una maquina engima con la ayuda de funciones de los strings en python, en este caso, declarando dos abecedarios mas al que usamos, para esto vamos a usar los metodos maketrans() y translate() para codificar y decodificar nuestra frase
# [texto del vínculo](https://www.w3schools.com/python/ref_string_translate.asp)

# %%
abecedario1 = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
abecedario2 = "abcdefghijklmnopqrstuvwxyz"
abecedario3 = "0123456789"

# variable: abecedario1 a convertir usando maketrans y translate a minusculas

traduccion = abecedario1.maketrans(abecedario1, abecedario2)

abecedario1 = abecedario1.translate(traduccion)

print(abecedario1)

# variable: abecedario2 a convertir usando maketrans y translate a mayusculas
traduccion = abecedario2.maketrans(abecedario2, abecedario1)

abecedario2 = abecedario2.translate(traduccion)

print(abecedario2)

# variable: abecedario3 a convertir usando maketrans y translate a numeros romanos
numeros_romanos = "ABCDEFGHIJ"
numeros_arabigos = "1234567890"

traduccion = abecedario3.maketrans(numeros_arabigos, numeros_romanos)

abecedario3 = abecedario3.translate(traduccion)

print(abecedario3)
# Out:
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# JABCDEFGHI

# %% [markdown]
# ## Ejercicio 3

# %% [markdown]
# Usando [regex](https://www.w3schools.com/python/python_regex.asp) complete, Tip: Esta pagina es de utilidad https://regexr.com/

# %%
import re

# Validar numeros
re.match("", "124456")

# Validar letras
re.match("", "alejo")

# Validar direccion ejemplos:
# Calle 22A # 43e - 46
# Carrera 10 # 43 - 46
# Calle 22 # 43e - 46

re.match("", "Calle 22A # 43e - 46")


# Validar correo electronico
# alejandro.jimenez@gov.co
# alejandrojimenez1234@gmail.com
re.match("", "alejandro.jimenez@gov.co")


textoCorreos = """
En nuestra organización, contamos con varias direcciones de correo electrónico para que puedas ponerte en contacto con nosotros:

Para consultas generales, escríbenos a info@organizacion.com.
Si necesitas soporte, contacta a soporte@organizacion.org.
Para temas de ventas, utiliza ventas@empresa.net.
Sin embargo, es importante tener cuidado con las direcciones incorrectas. Algunos ejemplos de correos no válidos incluyen:

@sinusuario.com (falta el nombre de usuario).
usuario@dominio (falta el dominio de nivel superior).
nombre@.com (hay un punto antes del dominio).
usuario@dominio.c (el dominio de nivel superior es demasiado corto).
nombre@dominio..com (hay un doble punto en el dominio).
nombre@dominio@com (hay más de un símbolo @).
invalido@dominio,com (el uso de una coma en lugar de un punto).
Para asegurar que tu mensaje llegue, utiliza direcciones como contacto@nuestroservicio.com o info@subdominio.org.
"""

# usando la variable textoCorreos, encuentre el correo "ventas@empresa.net" usando regex y el metodo search
re.search(r"ventas@empresa\.net", textoCorreos)
print(re.search(r"ventas@empresa\.net", textoCorreos))

# Encontrar las direcciones de correo validas del texto
re.findall(r"\b[\w\.-]+@[\w\.-]+\.\w+\b", textoCorreos)
print(re.findall(r"\b[\w\.-]+@[\w\.-]+\.\w+\b", textoCorreos))
# Out:
# <re.Match object; span=(282, 300), match='ventas@empresa.net'>
# ['info@organizacion.com', 'soporte@organizacion.org', 'ventas@empresa.net', 'usuario@dominio.c', 'nombre@dominio..com', 'contacto@nuestroservicio.com', 'info@subdominio.org']

# %% [markdown]
# ## Ejercicio 4

# %% [markdown]
# Datos: Listado de tweets que vamos a analizar y con los que trabajaremos

# %%
tweets = []
tweet1 = """ATENCIÓN 🚨 Reportan muerte de voluntario brasileño de vacuna de Oxford para
covid-19. Esto es lo que se conoce hasta el momento ►
 https://eltiempo.com/salud/muere-voluntario-de-la-vacuna-de-oxford-para-covid-19-en-brasil-544508?utm_medium=Social&utm_source=Twitter#Echobox=1603302840"""

tweet2 = """🚨 La vicepresidenta Marta Lucía Ramírez responde a críticas por no usar tapabocas en evento.
Días después de dicho encuentro, la vicepresidenta confirmó que había dado positivo en prueba de covid-19.
Esta fue su respuesta 👉 https://eltiempo.com/politica/gobierno/vicepresidente-marta-lucia-ramirez-responde-a-criticas-por-no-usar-tapabocas-en-evento-545337?utm_medium=Social&utm_source=Twitter#Echobox=1603722773"""

tweet3 = """España decretó estado de alarma para mitigar segunda ola de covid.
⬇️ https://eltiempo.com/mundo/europa/coronavirus-espana-decreta-estado-de-alarma-por-segunda-ola-de-la-pandemia-545194?utm_medium=Social&utm_source=Twitter#Echobox=1603669555"""

tweet4 = """Colombia superó el millón de casos de covid-19; ya hay 30.000 muertes. Más información aquí. ➡️"""

tweet5 = """Abrir las ventanas y aislar los pupitres reduce propagación del covid-19.
Esto dice una investigación ►
https://eltiempo.com/vida/educacion/estudio-abrir-las-ventanas-reduce-un-40-la-presencia-de-aerosoles-en-las-aulas-544679?utm_medium=Social&utm_source=Twitter#Echobox=1603396380"""

tweet6 = """Instituto Nacional de Salud estudia inmunidad del covid-19 en Medellín ►
https://www.eltiempo.com/colombia/medellin/covid-19-en-medellin-instituto-nacional-de-salud-estudia-inmunidad-del-covid-en-la-ciudad-544608?utm_medium=Social&utm_source=Twitter#Echobox=1603378778"""

tweet7 = """China prueba vacuna contra covid-19 en 60.000 personas sin efectos adversos ►
https://bit.ly/3dGOCoj"""

tweet8 = """Putin le ofrece gratis a la ONU la vacuna rusa contra el covid-19. 💉➡️
https://eltiempo.com/mundo/europa/vacuna-rusa-vladimir-putin-se-la-ofrece-gratis-a-la-onu-539268?utm_medium=Social&utm_source=Twitter#Echobox=1600825681"""

tweet9 = """🚨 ATENCIÓN 🚨 El Invima autorizó el reclutamiento de voluntarios para probar la vacuna de Johnson & Johnson en Colombia.
Acá le contamos dónde se van a llevar a cabo los ensayos en el país y qué debe saber si le interesa ser voluntario 👉 https://bit.ly/2GUpbmF"""

tweet10 = """Putin le ofrece gratis a la ONU la vacuna rusa contra el covid-19. Esta fue su oferta.  💉
https://eltiempo.com/mundo/europa/vacuna-rusa-vladimir-putin-se-la-ofrece-gratis-a-la-onu-539268?utm_medium=Social&utm_source=Twitter#Echobox=1600828246"""

tweets.append(tweet1)
tweets.append(tweet2)
tweets.append(tweet3)
tweets.append(tweet4)
tweets.append(tweet5)
tweets.append(tweet6)
tweets.append(tweet7)
tweets.append(tweet8)
tweets.append(tweet9)
tweets.append(tweet10)

print(tweets)

# %% [markdown]
# Como primer paso vamos a eliminar caracteres poco utiles usados en la escritura actual como lo son emojis, flechas, url que no son utiles en nuestro contexto de trabajo.
# Para lograr esto usaremos los metodos replace, lower y el lenguaje regex

# %%
# Importamos la libreria de regex
import re

# Patrones de todos los emojis, para ser removidos
emoji_pattern = re.compile(
    "["
    "\U0001F600-\U0001F64F"  # emoticons
    "\U0001F300-\U0001F5FF"  # symbols & pictographs
    "\U0001F680-\U0001F6FF"  # transport & map symbols
    "\U0001F1E0-\U0001F1FF"  # flags (iOS)
    "\U0001F1F2-\U0001F1F4"  # Macau flag
    "\U0001F1E6-\U0001F1FF"  # flags
    "\U0001F600-\U0001F64F"
    "\U00002702-\U000027B0"
    "\U000024C2-\U0001F251"
    "\U0001f926-\U0001f937"
    "\U0001F1F2"
    "\U0001F1F4"
    "\U0001F620"
    "\u200d"
    "\u2640-\u2642"
    "]+",
    flags=re.UNICODE,
)

# Ejemplo

# Primero quitemos los saltos de linea (\n) y las url que se encuentra en el tweet

# Quitamos salto de linea
tweets[0] = re.sub()

# Quitamos las url
tweets[0] = re.sub()

print("Sin saltos y urls:", tweets[0])

# Primero, pongamos el tweet en minuscula y remplacemoslo en la lista original

print("Minusculas:", tweets[0])

# Segundo, vamos a quitar algunos emojis y caracteres especiales que se encuentran dentro del tweet
tweets[0] = emoji_pattern.sub()
print("Sin emojis:", tweets[0])

# %% [markdown]
# Actividad: Realice los mismos pasos anteriores para los demas tweets de la lista

# %%
# Primero quitemos los saltos de linea (\n) y las url que se encuentra en el tweet

# Quitamos salto de linea
tweets[1] = re.sub()

# Quitamos las url
tweets[1] = re.sub()

print("Sin saltos y urls:", tweets[1])

# Primero, pongamos el tweet en minuscula y remplacemoslo en la lista original

print("Minusculas:", tweets[1])

# Segundo, vamos a quitar algunos emojis y caracteres especiales que se encuentran dentro del tweet
tweets[1] = emoji_pattern.sub()
print("Sin emojis:", tweets[1])


# Primero quitemos los saltos de linea (\n) y las url que se encuentra en el tweet

# Quitamos salto de linea
tweets[2] = re.sub()

# Quitamos las url
tweets[2] = re.sub()

print("Sin saltos y urls:", tweets[2])

# Primero, pongamos el tweet en minuscula y remplacemoslo en la lista original

print("Minusculas:", tweets[2])

# Segundo, vamos a quitar algunos emojis y caracteres especiales que se encuentran dentro del tweet
tweets[2] = emoji_pattern.sub()

print("Sin emojis:", tweets[2])


# Primero quitemos los saltos de linea (\n) y las url que se encuentra en el tweet

# Quitamos salto de linea
tweets[3] = re.sub()

# Quitamos las url
tweets[3] = re.sub()

print("Sin saltos y urls:", tweets[3])

# Primero, pongamos el tweet en minuscula y remplacemoslo en la lista original

print("Minusculas:", tweets[3])

# Segundo, vamos a quitar algunos emojis y caracteres especiales que se encuentran dentro del tweet
tweets[3] = emoji_pattern.sub()

print("Sin emojis:", tweets[3])

# Primero quitemos los saltos de linea (\n) y las url que se encuentra en el tweet

# Quitamos salto de linea
tweets[4] = re.sub()

# Quitamos las url
tweets[4] = re.sub()

print("Sin saltos y urls:", tweets[4])

# Primero, pongamos el tweet en minuscula y remplacemoslo en la lista original

print("Minusculas:", tweets[4])

# Segundo, vamos a quitar algunos emojis y caracteres especiales que se encuentran dentro del tweet

tweets[4] = emoji_pattern.sub()

print("Sin emojis:", tweets[4])

# Primero quitemos los saltos de linea (\n) y las url que se encuentra en el tweet

# Quitamos salto de linea

tweets[5] = re.sub()

# Quitamos las url

tweets[5] = re.sub()

print("Sin saltos y urls:", tweets[5])

# Primero, pongamos el tweet en minuscula y remplacemoslo en la lista original

print("Minusculas:", tweets[5])

# Segundo, vamos a quitar algunos emojis y caracteres especiales que se encuentran dentro del tweet

tweets[5] = emoji_pattern.sub()

print("Sin emojis:", tweets[5])

# Primero quitemos los saltos de linea (\n) y las url que se encuentra en el tweet

# Quitamos salto de linea

tweets[6] = re.sub()

# Quitamos las url

tweets[6] = re.sub()

print("Sin saltos y urls:", tweets[6])

# Primero, pongamos el tweet en minuscula y remplacemoslo en la lista original

print("Minusculas:", tweets[6])

# Segundo, vamos a quitar algunos emojis y caracteres especiales que se encuentran dentro del tweet

tweets[6] = emoji_pattern.sub()

print("Sin emojis:", tweets[6])

# Primero quitemos los saltos de linea (\n) y las url que se encuentra en el tweet

# Quitamos salto de linea

tweets[7] = re.sub()

# Quitamos las url

tweets[7] = re.sub()

print("Sin saltos y urls:", tweets[7])

# Primero, pongamos el tweet en minuscula y remplacemoslo en la lista original

print("Minusculas:", tweets[7])

# Segundo, vamos a quitar algunos emojis y caracteres especiales que se encuentran dentro del tweet

tweets[7] = emoji_pattern.sub()

print("Sin emojis:", tweets[7])

# Primero quitemos los saltos de linea (\n) y las url que se encuentra en el tweet

# Quitamos salto de linea

tweets[8] = re.sub()

# Quitamos las url

tweets[8] = re.sub()

print("Sin saltos y urls:", tweets[8])

# Primero, pongamos el tweet en minuscula y remplacemoslo en la lista original

print("Minusculas:", tweets[8])

# Segundo, vamos a quitar algunos emojis y caracteres especiales que se encuentran dentro del tweet

tweets[8] = emoji_pattern.sub()

print("Sin emojis:", tweets[8])

# Primero quitemos los saltos de linea (\n) y las url que se encuentra en el tweet

# Quitamos salto de linea

tweets[9] = re.sub()

# Quitamos las url

tweets[9] = re.sub()

print("Sin saltos y urls:", tweets[9])

# Primero, pongamos el tweet en minuscula y remplacemoslo en la lista original

print("Minusculas:", tweets[9])

# Segundo, vamos a quitar algunos emojis y caracteres especiales que se encuentran dentro del tweet

tweets[9] = emoji_pattern.sub()

print("Sin emojis:", tweets[9])

# %% [markdown]
# ## Ejercicio 5

# %% [markdown]
# Use [Pyspellchecker](https://pyspellchecker.readthedocs.io/en/latest/) para corregir la ortografia del texto, imprima para cada palabra mal escrita 2 candidatos para remplazar dicha palabra

# %%
# !pip install pyspellchecker
from spellchecker import SpellChecker

historia = """Un dai, en un pueblito lejado, vivya una nina lamada Lila que soñaba con aventurarses.
Cada mañana, ella se despertaba temprano para explorar el bosques cercano, donde los arboles eran altos y misteriosos.
Un día, mientras recogia flores, se encontro con un gato negro que parecia tener ojos que brillaban como estrelas.
Lila, intrigada, decidio seguir al gato, sin zaber que lo que iba a descubrir cambiaria su vida para siempre.
A medida que avanzaba, el sendero se tornaba mas oscuro y lleno de sombras, pero su curiosidad era mas fuerte que su miedo."""

# %% [markdown]
# FACULTAD DE MINAS<br>
# Sede Medellín

# %% [markdown]
# SINTELWEB<br>
# Grupo de Investigación<br>
# Sistemas Inteligentes
